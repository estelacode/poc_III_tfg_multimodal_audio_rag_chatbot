# %% [markdown]
# Speech to Text with Wav2Vec 2.0
# https://huggingface.co/docs/transformers/model_doc/wav2vec2
# https://www.kdnuggets.com/2021/03/speech-text-wav2vec.html

# %%
# Installing Transformer

# !pip install -q transformers

# %%
# Import necessary library

# For managing audio file
import librosa

#Importing Pytorch
import torch

#Importing Wav2Vec
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer, Wav2Vec2Processor

# %% [markdown]
# # Importing pre-trained Wav2Vec model

# %% [markdown]
# # Model: facebook/wav2vec2-base-960h

# %%
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:720: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(

# %%
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Test 1: red_sandals.wav

# %%
# Loading the audio file
audio1, rate1 = librosa.load("/content/red_sandals.wav", sr = 16000)
# printing audio
print(audio1)
# printing rate
print(rate1)

# Taking an input value
input_values1 = tokenizer(audio1, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits1 = model(input_values1).logits

# Storing predicted ids
prediction1 = torch.argmax(logits1, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription1 = tokenizer.batch_decode(prediction1)[0]

# Printing the transcription
print(transcription1)
# Out:
# [-1.2987584e-09  1.3496901e-09 -1.4188117e-09 ...  3.2008151e-04
#   2.5408113e-04  2.6457771e-04]
# 16000
# ALLO A'M LOOKING FOR RATSANDERS FOR CHRISTMAS EVENT

# %% [markdown]
# Test 2: red_sandals_2.wav

# %%
# Loading the audio file
audio2, rate2 = librosa.load("/content/red_sandals_2.wav", sr = 16000)
# printing audio
print(audio2)
# printing rate
print(rate2)

# Taking an input value
input_values2 = tokenizer(audio2, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits2 = model(input_values2).logits

# Storing predicted ids
prediction2 = torch.argmax(logits2, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription2 = tokenizer.batch_decode(prediction2)[0]

# Printing the transcription
print(transcription2)
# Out:
# [ 2.7994247e-09 -3.3669494e-09  3.9599399e-09 ...  3.6599959e-06
#  -3.6138546e-05  3.7275633e-05]
# 16000
# HALLO I'M LOOKING FOR GRET SANDAS FOR A CHRISTMAS EVENT

# %% [markdown]
# Test 3: white_sneakers.wav

# %%
# Loading the audio file
audio3, rate3 = librosa.load("/content/white_sneakers.wav", sr = 16000)
# printing audio
print(audio3)
# printing rate
print(rate3)

# Taking an input value
input_values3 = tokenizer(audio3, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits3 = model(input_values3).logits

# Storing predicted ids
prediction3 = torch.argmax(logits3, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription3 = tokenizer.batch_decode(prediction3)[0]

# Printing the transcription
print(transcription3)
# Out:
# [-5.4569682e-12 -4.5474735e-12  0.0000000e+00 ...  2.5080932e-05
#   3.8704871e-05 -6.9391535e-06]
# 16000
# HELLL I WOULD LIKE TO BUY WHITE  SNIGERS WITH COMFORTABLE ROBBER SOULS

# %% [markdown]
# # Model: wav2vec2-large-960h-lv60-self

# %%
 # load model and processor
processor_1 = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")

# %%
model_1 = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Loading the audio file
audio4, rate4 = librosa.load("/content/white_sneakers.wav", sr = 16000)
# printing audio
print(audio4)
# printing rate
print(rate4)

# Taking an input value
input_values4 = tokenizer(audio4, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits4 = model_1(input_values4).logits

# Storing predicted ids
prediction4 = torch.argmax(logits4, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription4 = tokenizer.batch_decode(prediction4)[0]

# Printing the transcription
print(transcription4)
# Out:
# [-5.4569682e-12 -4.5474735e-12  0.0000000e+00 ...  2.5080932e-05
#   3.8704871e-05 -6.9391535e-06]
# 16000
# HELLO I WOULD LIKE TO BUY WHITES NIGGERS WITH COMFORTABLE RUBBER SOULS

# %%
# Loading the audio file
audio5, rate5 = librosa.load("/content/red_sandals_2.wav", sr = 16000)
# printing audio
print(audio5)
# printing rate
print(rate5)

# Taking an input value
input_values5 = tokenizer(audio5, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits5 = model_1(input_values5).logits

# Storing predicted ids
prediction5 = torch.argmax(logits5, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription5 = tokenizer.batch_decode(prediction5)[0]

# Printing the transcription
print(transcription5)
# Out:
# [ 2.7994247e-09 -3.3669494e-09  3.9599399e-09 ...  3.6599959e-06
#  -3.6138546e-05  3.7275633e-05]
# 16000
# HELLO I'M LOOKING FOR GREAT SANDALS FOR A CHRISTMAS EVENT

# %%
# Loading the audio file
audio6, rate6 = librosa.load("/content/red_sandals_short.wav", sr = 16000)
# printing audio
print(audio6)
# printing rate
print(rate6)

# Taking an input value
input_values6 = tokenizer(audio6, return_tensors = "pt").input_values

# Storing logits (non-normalized prediction values)
logits6 = model_1(input_values6).logits

# Storing predicted ids
prediction6 = torch.argmax(logits6, dim = -1)

## Converting audio to text
# Passing the prediction to the tokenzer decode to get the transcription
transcription6 = tokenizer.batch_decode(prediction6)[0]

# Printing the transcription
print(transcription6)
# Out:
# [ 1.4260877e-09 -1.6880222e-09  1.9790605e-09 ... -1.2246368e-05
#   3.7411468e-05 -3.7673817e-05]
# 16000
# FRED SANDERS
