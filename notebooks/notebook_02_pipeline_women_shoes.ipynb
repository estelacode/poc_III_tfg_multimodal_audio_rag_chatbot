# %%
from entregable_tfg_chatbot.etl import load_csv, filter_rows, select_columns, remove_incorrect_cataloged_rows, get_images_json_to_list, preprocessing_woman_images,get_indices_images, get_one_image_of_list_women, create_folder, copy_images_to_folder, create_txt_files
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from PIL import Image
import shutil
import os

# %%
 # Load the CSV file
df = load_csv('../data/store_zara_data/store_zara.csv')

# %%
# Filter and select columns
df_row_filtered = filter_rows(df, "terms =='shoes'")

# %%
# Select relevant columns
df_cols_selected = select_columns(df_row_filtered, ['name','description','price','currency','section','terms','image_downloads'])

# %%
# Filter rows with section == WOMAN
df_woman = filter_rows(df_cols_selected, "section =='WOMAN'").reset_index(drop=True)

# %%
 # Remove incorrect cataloged rows in df_woman
df_woman_removed_rows = remove_incorrect_cataloged_rows(df_woman, [[273,274,275,276,277]])

# %%
# convert json to list in image_downloads
df_woman_removed_rows.loc[:,'image_downloads']= df_woman_removed_rows['image_downloads'].apply(get_images_json_to_list)

# %%
# get the total number of images
df_woman_removed_rows.loc[:,'total_images'] = df_woman_removed_rows['image_downloads'].apply(len)

# %%
df_woman_removed_rows.head(2)
# Out:
#                       name                                        description  \
# 0  PEARL HEELED SLINGBACKS  Slingback heels with front pearl detail. Point...
# 1     LEATHER BALLET FLATS  Mary Jane style leather ballet flats. Buckled ...
#
#    price currency section  terms  \
# 0   79.9      USD   WOMAN  shoes
# 1   59.9      USD   WOMAN  shoes
#
#                                      image_downloads  total_images
# 0  [79d241c5-2dcc-4fc2-8520-3611fe0be740, a4628bf...             9
# 1  [3c5a4b1d-407b-4683-8489-795e1177aa4a, 769a6f4...             5

# %%
def show_images(lista_imagenes):
    """ Funcion para mostrar las imagenes"""
    fig, axs = plt.subplots(nrows=1, ncols=len(lista_imagenes), figsize=(30,5))
    for i, image in enumerate(lista_imagenes):
        image_path = "../data/store_zara_data/images/zara/" + str(image) + ".jpg"
        image = Image.open(image_path).convert("RGB")
        axs[i].imshow(image)
        axs[i].axis('off')
    plt.tight_layout() #  ajustar automáticamente el tamaño del gráfico y los márgenes para que se ajuste correctamente a la ventana.
    plt.show()

# %% [markdown]
# ## Image List Size: 27

# %%
# fila: 261
size=27
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [261]

# %%
especial_indexes = [261]
x= 6
y=11
w=0
z=0

preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 12

# %%
# fila: 280
size=12
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [280]

# %%
especial_indexes = [280]
x= 7
y=11
w=0
z=0

preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 11

# %%
# filas: [98, 133, 192, 255, 263]
size=11
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [98, 133, 192, 255, 263]

# %%
especial_indexes = [192]
x= 4
y=8
w=6
z=10
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 10

# %%
# filas: [64, 126, 144, 148, 176, 222, 235, 239, 243, 270, 272]
size=10
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [64, 126, 144, 148, 176, 222, 235, 239, 243, 270, 272]

# %%
especial_indexes = [148,235,239,270,272]
x= 4
y=9
w=5
z=9
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 9

# %%
# filas: [0, 29, 60, 62, 65, 84, 85, 87, 95, 99, 105, 107, 113, 121, 123, 136, 137, 140, 166, 173, 184, 189, 190, 197, 201, 202, 205, 217, 218, 219, 221, 231, 236, 240, 244, 253, 254, 262, 274, 275, 276, 279]
size=9
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [0, 29, 60, 62, 65, 84, 85, 87, 95, 99, 105, 107, 113, 121, 123, 136, 137, 140, 166, 173, 184, 189, 190, 197, 201, 202, 205, 217, 218, 219, 221, 231, 236, 240, 244, 253, 254, 262, 274, 275, 276, 279]

# %%
especial_indexes = [0,62,65,85,87,123,140,166,184,217,221]
x= 3
y=8
w=4
z=8
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 8

# %%
indice_images = [164]
especial_indexes = [164]
x= 4
y=8
w=0
z=0
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %%
indice_images = [31]
especial_indexes = [31]
x= 1
y=6
w=0
z=0
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %%
# filas: [2, 21, 26, 31, 33, 40, 50, 51, 75, 79, 88, 92, 103, 109, 125, 131, 134, 138, 153, 156, 160, 164, 168, 169, 181, 186, 193, 194, 198, 203, 209, 210, 214, 215, 216, 228, 232, 238, 245, 249, 250, 251, 252, 258, 264]
size=8
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [2, 21, 26, 31, 33, 40, 50, 51, 75, 79, 88, 92, 103, 109, 125, 131, 134, 138, 153, 156, 160, 164, 168, 169, 181, 186, 193, 194, 198, 203, 209, 210, 214, 215, 216, 228, 232, 238, 245, 249, 250, 251, 252, 258, 264]

# %%
indice_images.remove(31)
indice_images.remove(164)

# %%
especial_indexes = [21,33,88,92,168,186,194,209,245,249]
x=2
y=7
w=3
z=8
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 7

# %%
indice_images = [112]
especial_indexes = [112]
x= 0
y=5
w=0
z=0
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %%
# filas: [7, 11, 13, 14, 16, 18, 23, 24, 25, 27, 28, 30, 32, 34, 37, 38, 41, 42, 43, 47, 63, 66, 67, 68, 69, 70, 72, 74, 76, 81, 89, 94, 102, 110, 111, 112, 115, 119, 127, 129, 132, 135, 147, 150, 152, 155, 157, 161, 163, 171, 172, 174, 179, 185, 187, 188, 195, 196, 200, 206, 207, 223, 224, 229, 230, 233, 246, 247, 257, 268, 271, 273]
size=7
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [7, 11, 13, 14, 16, 18, 23, 24, 25, 27, 28, 30, 32, 34, 37, 38, 41, 42, 43, 47, 63, 66, 67, 68, 69, 70, 72, 74, 76, 81, 89, 94, 102, 110, 111, 112, 115, 119, 127, 129, 132, 135, 147, 150, 152, 155, 157, 161, 163, 171, 172, 174, 179, 185, 187, 188, 195, 196, 200, 206, 207, 223, 224, 229, 230, 233, 246, 247, 257, 268, 271, 273]

# %%
indice_images.remove(112)

# %%
especial_indexes = [13,18,63]
x=3
y=7
w=2
z=7
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 6

# %%
indice_images_6 = [73,120,122,128,139,175,237]
especial_indexes = [73,120,122,128,139,175,237]
x= 2
y=6
w=0
z=0
preprocessing_woman_images(df_woman_removed_rows, indice_images_6, especial_indexes, x,y,w,z)

# %%
# filas: [4, 8, 10, 22, 45, 48, 53, 54, 56, 58, 61, 71, 73, 78, 82, 83, 90, 96, 97, 100, 101, 108, 116, 117, 118, 120, 122, 128, 139, 141, 142, 145, 149, 151, 154, 170, 175, 177, 178, 180, 182, 191, 199, 204, 208, 211, 225, 226, 237, 248, 256, 259, 266, 267, 277]
size=6
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [4, 8, 10, 22, 45, 48, 53, 54, 56, 58, 61, 71, 73, 78, 82, 83, 90, 96, 97, 100, 101, 108, 116, 117, 118, 120, 122, 128, 139, 141, 142, 145, 149, 151, 154, 170, 175, 177, 178, 180, 182, 191, 199, 204, 208, 211, 225, 226, 237, 248, 256, 259, 266, 267, 277]

# %%
for i in indice_images_6:
    indice_images.remove(i)

print(indice_images)
# Out:
# [4, 8, 10, 22, 45, 48, 53, 54, 56, 58, 61, 71, 78, 82, 83, 90, 96, 97, 100, 101, 108, 116, 117, 118, 141, 142, 145, 149, 151, 154, 170, 177, 178, 180, 182, 191, 199, 204, 208, 211, 225, 226, 248, 256, 259, 266, 267, 277]

# %%
especial_indexes = [48,154,180,191,199,204]
x=0
y=5
w=1
z=6
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 5

# %%
# filas: [1, 3, 5, 6, 9, 15, 17, 19, 20, 35, 39, 46, 49, 52, 55, 57, 59, 77, 80, 86, 91, 93, 104, 106, 114, 124, 130, 143, 158, 159, 162, 165, 167, 183, 212, 213, 220, 227, 234, 241, 242, 260, 265, 269, 278, 281]
size=5
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [1, 3, 5, 6, 9, 15, 17, 19, 20, 35, 39, 46, 49, 52, 55, 57, 59, 77, 80, 86, 91, 93, 104, 106, 114, 124, 130, 143, 158, 159, 162, 165, 167, 183, 212, 213, 220, 227, 234, 241, 242, 260, 265, 269, 278, 281]

# %%
especial_indexes = [5,15,17,20,49,93,283]
x=1
y=5
w=0
z=5
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 4

# %%
# filas: [12, 36, 146]
size=4
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [12, 36, 146]

# %%
especial_indexes = [12]
x=1
y=4
w=0
z=3
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %% [markdown]
# ## Image List Size: 2

# %%
#fila: 2 
size=2
indice_images = get_indices_images(df_woman_removed_rows,size)
print(indice_images)
# Out:
# [44]

# %%
especial_indexes = [44]
x=0
y=1
w=0
z=0
preprocessing_woman_images(df_woman_removed_rows, indice_images, especial_indexes, x,y,w,z)

# %%
df_woman_removed_rows.head(2)
# Out:
#                       name                                        description  \
# 0  PEARL HEELED SLINGBACKS  Slingback heels with front pearl detail. Point...
# 1     LEATHER BALLET FLATS  Mary Jane style leather ballet flats. Buckled ...
#
#    price currency section  terms  \
# 0   79.9      USD   WOMAN  shoes
# 1   59.9      USD   WOMAN  shoes
#
#                                      image_downloads  total_images
# 0  [82aaf07d-4981-46d9-ab54-56d82c40cfa5, ea8b997...             9
# 1  [3c5a4b1d-407b-4683-8489-795e1177aa4a, 769a6f4...             5

# %%
df_woman_removed_rows.loc[:,'images_cleaned_count'] = df_woman_removed_rows['image_downloads'].apply(len)

# %%
df_woman_removed_rows.head(2)
# Out:
#                       name                                        description  \
# 0  PEARL HEELED SLINGBACKS  Slingback heels with front pearl detail. Point...
# 1     LEATHER BALLET FLATS  Mary Jane style leather ballet flats. Buckled ...
#
#    price currency section  terms  \
# 0   79.9      USD   WOMAN  shoes
# 1   59.9      USD   WOMAN  shoes
#
#                                      image_downloads  total_images  \
# 0  [82aaf07d-4981-46d9-ab54-56d82c40cfa5, ea8b997...             9
# 1  [3c5a4b1d-407b-4683-8489-795e1177aa4a, 769a6f4...             5
#
#    images_cleaned_count
# 0                     5
# 1                     5

# %%
ax = plt.subplots(nrows=1, ncols=1, figsize=(20,5))
ax = sns.countplot(data=df_woman_removed_rows, x='images_cleaned_count', legend=True)

# %%
# size=5
# indice_images = get_indices_images(df_woman_removed_rows,size, 'images_cleaned_count')
# print(indice_images)

# %%
# for i in range(0, len(indice_images)):
#     print(i, indice_images[i])
#     print(show_images(df_woman_removed_rows.loc[i, 'image_downloads']))

# %%
# show_images(df_woman_removed_rows.loc[50, 'image_downloads'])

# %%
df_woman_removed_rows.head(2)
# Out:
#                       name                                        description  \
# 0  PEARL HEELED SLINGBACKS  Slingback heels with front pearl detail. Point...
# 1     LEATHER BALLET FLATS  Mary Jane style leather ballet flats. Buckled ...
#
#    price currency section  terms  \
# 0   79.9      USD   WOMAN  shoes
# 1   59.9      USD   WOMAN  shoes
#
#                                      image_downloads  total_images  \
# 0  [82aaf07d-4981-46d9-ab54-56d82c40cfa5, ea8b997...             9
# 1  [3c5a4b1d-407b-4683-8489-795e1177aa4a, 769a6f4...             5
#
#    images_cleaned_count
# 0                     5
# 1                     5

# %%
# Get one image of list 
df_woman_one_image = get_one_image_of_list_women(df_woman_removed_rows,0,2,3,1)

# %%
# Select final columns
df_woman_final_cols= select_columns(df_woman_one_image, ['name','description','price','currency','iso_image'])
df_woman_final_cols.head(3)
# Out:
#                         name  \
# 0    PEARL HEELED SLINGBACKS
# 1       LEATHER BALLET FLATS
# 2  HIGH HEEL SLINGBACK PUMPS
#
#                                          description  price currency  \
# 0  Slingback heels with front pearl detail. Point...   79.9      USD
# 1  Mary Jane style leather ballet flats. Buckled ...   59.9      USD
# 2  Heeled slingbacks with faux patent leather fin...   49.9      USD
#
#                               iso_image
# 0  ea8b9976-7cda-4e4c-9926-b357b1aa65c7
# 1  769a6f42-94a6-451b-9014-5fcf1100d212
# 2  19b80e65-67a9-45f8-8139-e7b1da2ab448

# %%
def create_folder(path):
    return os.mkdir(path)

# %%
image_folder_path = "../data/women_images"
create_folder(image_folder_path)

# %% [markdown]
# ### Copiar imagenes definitivas calzado mujer al directorio final  'women_images'

# %%
path = "../data/store_zara_data/images/zara/"
column = 'iso_image'
copy_images_to_folder(df_woman_final_cols, column, path, image_folder_path)

# %% [markdown]
# ## Guardar descipciones producto calzado mujer en txt.

# %%
def create_txt_files(df: pd.DataFrame, destination_dir: str):
    for row in df.iterrows():
        name = 'Name: ' + str(row[1]['name']) + '\n'
        descripcion = 'Description: ' + str(row[1]['description']) + '\n'
        price = 'Price: ' + str(row[1]['price']) + '\n'
        currency = 'Currency: ' + str(row[1]['currency']) 
        images_reference = row[1]['iso_image']
        with open('../data/women_txt/'+ images_reference + '.txt', 'w') as f:
            f.write(name) 
            f.write(descripcion)
            f.write(price)
            f.write(currency)

# %%
txt_folder_path = "../data/women_txt"
create_folder(txt_folder_path)

# %%
create_txt_files(df_woman_final_cols, txt_folder_path)

# %% [markdown]
# ## Guardar csv file definitvo calzado mujer.

# %%
# Save dataframe final 
df_woman_final_cols.to_csv('../data/shoes_woman_etl.csv', index=False)

# %% [markdown]
# #### Mostrar galería de imágenes de producto calzado mujer final

# %%
def show_images17x17(lista_imagenes):
    """ Funcion para mostrar las imagenes"""
    fig, axs = plt.subplots(nrows=17, ncols=17, figsize=(10,10))
    for i in range(17):
        for j in range(17):
            if i * 17 + j < len(lista_imagenes):
                image_path = "../data/store_zara_data/images/zara/" + str(lista_imagenes[i * 17 + j]) + ".jpg"
                image = Image.open(image_path).convert("RGB")
                axs[i, j].imshow(image)
                axs[i, j].axis('off')
    plt.tight_layout()
    plt.show()
    return fig

# %%
total_iso_images_woman =df_woman_final_cols['iso_image'].to_list()
fig = show_images17x17(total_iso_images_woman)

# %%
# Exportar la figura a un archivo JPG
fig.savefig('../data/women_shoes_output.jpg', dpi=300)
